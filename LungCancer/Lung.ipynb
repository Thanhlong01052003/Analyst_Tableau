# %%
import pandas as pd

# %%
df = pd.read_csv('cancer patient data sets.csv')
df.drop(columns=['Patient Id'], inplace=True)
df.drop(columns=['index'], inplace=True)

# %%
col = df.columns.tolist()
col
# Out:
# ['Age',
#  'Gender',
#  'Air Pollution',
#  'Alcohol use',
#  'Dust Allergy',
#  'OccuPational Hazards',
#  'Genetic Risk',
#  'chronic Lung Disease',
#  'Balanced Diet',
#  'Obesity',
#  'Smoking',
#  'Passive Smoker',
#  'Chest Pain',
#  'Coughing of Blood',
#  'Fatigue',
#  'Weight Loss',
#  'Shortness of Breath',
#  'Wheezing',
#  'Swallowing Difficulty',
#  'Clubbing of Finger Nails',
#  'Frequent Cold',
#  'Dry Cough',
#  'Snoring',
#  'Level']

# %%
Age = [df['Age'].tolist()]
Gender = [df['Gender'].tolist()]
Air_Pollution = [df['Air Pollution'].tolist()]
Alcohol_use = [df['Alcohol use'].tolist()]
Dust_Allergy = [df['Dust Allergy'].tolist()]
Occupational_Hazards = [df['OccuPational Hazards'].tolist()]
Genetic_Risk = [df['Genetic Risk'].tolist()]
Chronic_Lung_Disease = [df['chronic Lung Disease'].tolist()]
Balanced_Diet = [df['Balanced Diet'].tolist()]
Obesity = [df['Obesity'].tolist()]
Smoking = [df['Smoking'].tolist()]
Passive_Smoker = [df['Passive Smoker'].tolist()]
Chest_Pain = [df['Chest Pain'].tolist()]
Coughing_of_Blood = [df['Coughing of Blood'].tolist()]
Fatigue = [df['Fatigue'].tolist()]
Weight_Loss = [df['Weight Loss'].tolist()]
Shortness_of_Breath = [df['Shortness of Breath'].tolist()]
Wheezing = [df['Wheezing'].tolist()]
Swallowing_Difficulty = [df['Swallowing Difficulty'].tolist()]
Clubbing_of_Finger_Nails = [df['Clubbing of Finger Nails'].tolist()]
Frequent_Cold = [df['Frequent Cold'].tolist()]
Dry_Cough = [df['Dry Cough'].tolist()]
Snoring = [df['Snoring'].tolist()]
Level = [df['Level'].tolist()]

# %%
dic={
col[0]: Age,
col[1]: Gender,
col[2]: Air_Pollution,
col[3]: Alcohol_use,
col[4]: Dust_Allergy,
col[5]: Occupational_Hazards,
col[6]: Genetic_Risk,
col[7]: Chronic_Lung_Disease,
col[8]: Balanced_Diet,
col[9]: Obesity,
col[10]: Smoking,
col[11]: Passive_Smoker,
col[12]: Chest_Pain,
col[13]: Coughing_of_Blood,
col[14]: Fatigue,
col[15]: Weight_Loss,
col[16]: Shortness_of_Breath,
col[17]: Wheezing,
col[18]: Swallowing_Difficulty,
col[19]: Clubbing_of_Finger_Nails,
col[20]: Frequent_Cold,
col[21]: Dry_Cough,
col[22]: Snoring,
col[23]: Level,
}

# %%
df = pd.DataFrame(dic)
df
# Out:
#                                                  Age  \
# 0  [33, 17, 35, 37, 46, 35, 52, 28, 35, 46, 44, 6...
#
#                                               Gender  \
# 0  [1, 1, 1, 1, 1, 1, 2, 2, 2, 1, 1, 2, 2, 1, 2, ...
#
#                                        Air Pollution  \
# 0  [2, 3, 4, 7, 6, 4, 2, 3, 4, 2, 6, 6, 4, 6, 3, ...
#
#                                          Alcohol use  \
# 0  [4, 1, 5, 7, 8, 5, 4, 1, 5, 3, 7, 8, 5, 7, 1, ...
#
#                                         Dust Allergy  \
# 0  [5, 5, 6, 7, 7, 6, 5, 4, 6, 4, 7, 7, 6, 7, 4, ...
#
#                                 OccuPational Hazards  \
# 0  [4, 3, 5, 7, 7, 5, 4, 3, 5, 2, 7, 7, 6, 7, 2, ...
#
#                                         Genetic Risk  \
# 0  [3, 4, 5, 6, 7, 5, 3, 2, 6, 4, 7, 7, 5, 6, 3, ...
#
#                                 chronic Lung Disease  \
# 0  [2, 2, 4, 7, 6, 4, 2, 3, 5, 3, 6, 6, 4, 7, 2, ...
#
#                                        Balanced Diet  \
# ...

# %%
df.to_excel('output2.xlsx')
